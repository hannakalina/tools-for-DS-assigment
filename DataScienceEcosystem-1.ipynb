# %% [markdown]
# # Data Science Tools and Ecosystem

# %% [markdown]
# In this notebook, Data Science Tools and Ecosystem are summarized.

# %% [markdown]
# Objectives:
#
#
# *   List of the popular languages for Data Scientists
# *   List of the commonly used python libraries for Data Scientists
# *   List of Data Science tools

# %% [markdown]
# Some of the popular languages that Data Scientists use are:
#
#
# 1.   Python
# 2.   R
# 3.   SQL
# 4.   Julia

# %% [markdown]
# Some of the commonly used libraries used by Data Scientists include:
#
#
# 1.   Pandas
# 2.   Matplotlib
# 3.   Numpy
# 4.   Seaborn
# 5.   Scikit-learn

# %% [markdown]
# | Data Science Tools |
# |--------------------|
# | Jupyter Notebook  |
# | RStudio           |
# | Apache Zeppelin   |

# %% [markdown]
# ### Below are a few examples of evaluating arithmetic expressions in Python.
#
# - **Addition:** `3 + 5 = 8`
# - **Subtraction:** `10 - 4 = 6`
# - **Multiplication:** `6 * 7 = 42`
# - **Division:** `20 / 5 = 4.0`
# - **Exponentiation:** `2 ** 3 = 8`
# - **Modulus (Remainder):** `10 % 3 = 1`
# - **Order of Operations:** `(3 + 5) * 2 = 16`

# %%
# This a simple arithmetic expression to mutiply then add integers
(3*4)+5
# Out:
# 17

# %%
# This will convert 200 minutes to hours by diving by 60
minutes = 200
hours = minutes // 60
minutes_left = minutes % 60
print(f"{minutes} minutes contain: {hours} hours, {minutes_left} minutes")
# Out:
# 200 minutes contain: 3 hours, 20 minutes

# %% [markdown]
# ## Author
# *Hanna Kalina*
